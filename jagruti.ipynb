# %% [markdown]
# <a href="https://colab.research.google.com/github/jagrutigoudu-cpu/demo/blob/main/jagruti.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("kutun")   #print name
# Out:
# kutun
